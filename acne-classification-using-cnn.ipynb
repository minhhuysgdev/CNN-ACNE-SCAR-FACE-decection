# %% [markdown]
# <a href="https://www.kaggle.com/code/zulqarnain11/acne-classification-using-cnn?scriptVersionId=267310242" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Acne Classification Using CNN
# ## Goal:
# Build a deep learning model to classify acne types using a CNN model, while addressing dataset imbalance through oversampling and augmentation.

# %% [markdown]
# ## ----------------------------
# ## 1. IMPORTS
# ## ----------------------------

# %%
pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in ./.venv/lib/python3.13/site-packages (0.3.13)
# Requirement already satisfied: packaging in ./.venv/lib/python3.13/site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.13/site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in ./.venv/lib/python3.13/site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.13/site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests->kagglehub) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.13/site-packages (from requests->kagglehub) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom, Rescaling
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
from sklearn.utils.class_weight import compute_class_weight
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# ## 📦 2. Download Dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("tiswan14/acne-dataset-image")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/huynguyen/.cache/kagglehub/datasets/tiswan14/acne-dataset-image/versions/1

# %% [markdown]
# ## 📂 3. Dataset Paths & Parameters

# %%
base_dir = os.path.join(path, "AcneDataset")
train_dir = os.path.join(base_dir, "train")
valid_dir = os.path.join(base_dir, "valid")
test_dir  = os.path.join(base_dir, "test")

# %%
train_dir
# Out:
# '/Users/huynguyen/.cache/kagglehub/datasets/tiswan14/acne-dataset-image/versions/1/AcneDataset/train'

# %% [markdown]
# ## 🧠 4. Load Datasets

# %%
# ----------------------------
# PARAMETERS
# ----------------------------
BATCH_SIZE = 32
IMAGE_SIZE = 128

# ----------------------------
# LOAD DATASETS
# ----------------------------
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir, label_mode='int', image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE, shuffle=True
)

valid_ds = tf.keras.preprocessing.image_dataset_from_directory(
    valid_dir, label_mode='int', image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE, shuffle=False
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir, label_mode='int', image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE, shuffle=False
)

class_names = train_ds.class_names
print("Classes:", class_names)
# Out:
# Found 2778 files belonging to 5 classes.
# Found 921 files belonging to 5 classes.
# Found 918 files belonging to 5 classes.
# Classes: ['Blackheads', 'Cyst', 'Papules', 'Pustules', 'Whiteheads']

# %% [markdown]
# ## 🖼️ 5. Visualize Sample Images

# %%
for image, label in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(image[i].numpy().astype("uint8"))

        label_index = label[i].numpy()
        plt.title(class_names[label_index])

        plt.axis("off")
# Out:
# 2025-12-11 20:11:16.692568: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ## 📊 6. Class Distribution

# %%
for folder in ['train', 'valid', 'test']:
    folder_path = os.path.join(base_dir, folder)
    for cls in os.listdir(folder_path):
        cls_path = os.path.join(folder_path, cls)
        if os.path.isdir(cls_path):  # Only count directories
            print(f"{folder}/{cls}:", len(os.listdir(cls_path)))
# Out:
# train/Whiteheads: 193
# train/Papules: 621
# train/Pustules: 584
# train/Cyst: 645
# train/Blackheads: 735
# valid/Whiteheads: 49
# valid/Papules: 209
# valid/Pustules: 217
# valid/Cyst: 206
# valid/Blackheads: 240
# test/Whiteheads: 57
# test/Papules: 202
# test/Pustules: 205
# test/Cyst: 189
# test/Blackheads: 265

# %% [markdown]
# ### 📌 Observation:
# Whiteheads (193 images) are underrepresented, which can bias the model.
# We'll fix this using oversampling and augmentation.

# %% [markdown]
# ## ⚖️ 7. Compute Class Weights

# %%
counts = [735, 645, 621, 584, 193]
classes = np.array([0,1,2,3,4])
y = np.repeat(classes, counts)
class_weight_dict = dict(zip(classes, compute_class_weight('balanced', classes=classes, y=y)))
print("Class weights:", class_weight_dict)
# Out:
# Class weights: {np.int64(0): np.float64(0.7559183673469387), np.int64(1): np.float64(0.8613953488372093), np.int64(2): np.float64(0.8946859903381642), np.int64(3): np.float64(0.9513698630136986), np.int64(4): np.float64(2.8787564766839377)}

# %% [markdown]
# ## 🔧 8. Preprocessing & Normalization

# %%
normalization_layer = Rescaling(1./255)

train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
valid_ds = valid_ds.map(lambda x, y: (normalization_layer(x), y))
test_ds = test_ds.map(lambda x, y: (normalization_layer(x), y))

# %% [markdown]
# ## 🔁 9. Data Augmentation

# %%
data_augmentation = Sequential([
    RandomFlip("horizontal_and_vertical"),
    RandomRotation(0.15),
    RandomZoom(0.15)
])

# %% [markdown]
# ## 🔄 10. Oversampling Minority Class (Whiteheads)

# %%
# Unbatch the dataset
train_ds_unbatched = train_ds.unbatch()

# Split dataset by class
class_datasets = []
for i in range(len(class_names)):
    class_datasets.append(train_ds_unbatched.filter(lambda x, y: y==i))

# Oversample minority class (Whiteheads, index 4)
target_count = max(counts)
minority_index = 4
repeat_times = target_count // counts[minority_index]
remainder = target_count % counts[minority_index]

oversampled_class = class_datasets[minority_index].repeat(repeat_times)
oversampled_class = oversampled_class.concatenate(class_datasets[minority_index].take(remainder))
class_datasets[minority_index] = oversampled_class

# Combine all classes
balanced_ds = class_datasets[0]
for ds in class_datasets[1:]:
    balanced_ds = balanced_ds.concatenate(ds)

# Shuffle, augment, and batch correctly
balanced_ds = balanced_ds.shuffle(5000)
balanced_ds = balanced_ds.map(lambda x, y: (data_augmentation(x, training=True), y))
balanced_ds = balanced_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ### ✅ Result:
# The dataset is now balanced across all acne types.

# %%
valid_ds = valid_ds.cache().prefetch(tf.data.AUTOTUNE)
test_ds  = test_ds.cache().prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ## 🧰 11. Build CNN Model

# %%
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(IMAGE_SIZE, IMAGE_SIZE,3)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(256, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.5),
    Dense(len(class_names), activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 12, 12, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 4, 4, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 667,845 (2.55 MB)
#  Trainable params: 667,845 (2.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 🏋️‍♂️ 12. Train Model

# %%
# ----------------------------
# CALLBACKS
# ----------------------------
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)

# ----------------------------
# TRAIN MODEL
# ----------------------------
history = model.fit(
    balanced_ds,
    validation_data=valid_ds,
    epochs=50,
    class_weight=class_weight_dict,
    callbacks=[early_stop, lr_scheduler],
    verbose=2
)
# Out:
# Epoch 1/50
# 2025-12-11 20:12:13.527160: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 104/104 - 22s - 212ms/step - accuracy: 0.2431 - loss: 1.8127 - val_accuracy: 0.1629 - val_loss: 1.6935 - learning_rate: 0.0010
# Epoch 2/50
# 104/104 - 20s - 190ms/step - accuracy: 0.3250 - loss: 1.5794 - val_accuracy: 0.2063 - val_loss: 1.6042 - learning_rate: 0.0010
# Epoch 3/50
# 2025-12-11 20:12:54.601242: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 104/104 - 21s - 202ms/step - accuracy: 0.3322 - loss: 1.5324 - val_accuracy: 0.1650 - val_loss: 1.7898 - learning_rate: 0.0010
# Epoch 4/50
# 104/104 - 21s - 202ms/step - accuracy: 0.3470 - loss: 1.4819 - val_accuracy: 0.2193 - val_loss: 1.6193 - learning_rate: 0.0010
# Epoch 5/50
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 104/104 - 21s - 205ms/step - accuracy: 0.3554 - loss: 1.4347 - val_accuracy: 0.2302 - val_loss: 1.6393 - learning_rate: 0.0010
# Epoch 6/50
# 104/104 - 19s - 184ms/step - accuracy: 0.3910 - loss: 1.3292 - val_accuracy: 0.2617 - val_loss: 1.5913 - learning_rate: 5.0000e-04
# Epoch 7/50
# 2025-12-11 20:14:15.232039: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 104/104 - 19s - 183ms/step - accuracy: 0.4033 - loss: 1.2906 - val_accuracy: 0.3051 - val_loss: 1.4776 - learning_rate: 5.0000e-04
# Epoch 8/50
# 104/104 - 20s - 193ms/step - accuracy: 0.4265 - loss: 1.2369 - val_accuracy: 0.3170 - val_loss: 1.4914 - learning_rate: 5.0000e-04
# Epoch 9/50
# 104/104 - 20s - 195ms/step - accuracy: 0.4500 - loss: 1.2015 - val_accuracy: 0.3257 - val_loss: 1.5112 - learning_rate: 5.0000e-04
# Epoch 10/50
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 104/104 - 20s - 188ms/step - accuracy: 0.4560 - loss: 1.1526 - val_accuracy: 0.2997 - val_loss: 1.5049 - learning_rate: 5.0000e-04
# Epoch 11/50
# 104/104 - 22s - 215ms/step - accuracy: 0.4883 - loss: 1.0986 - val_accuracy: 0.3811 - val_loss: 1.4219 - learning_rate: 2.5000e-04
# Epoch 12/50
# 104/104 - 20s - 196ms/step - accuracy: 0.4949 - loss: 1.0683 - val_accuracy: 0.4191 - val_loss: 1.3484 - learning_rate: 2.5000e-04
# Epoch 13/50
# 104/104 - 20s - 192ms/step - accuracy: 0.5048 - loss: 1.0420 - val_accuracy: 0.3757 - val_loss: 1.4279 - learning_rate: 2.5000e-04
# Epoch 14/50
# 104/104 - 21s - 199ms/step - accuracy: 0.5169 - loss: 1.0017 - val_accuracy: 0.4528 - val_loss: 1.2917 - learning_rate: 2.5000e-04
# Epoch 15/50
# 2025-12-11 20:16:58.336200: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 104/104 - 20s - 190ms/step - accuracy: 0.5533 - loss: 0.9591 - val_accuracy: 0.4691 - val_loss: 1.2715 - learning_rate: 2.5000e-04
# Epoch 16/50
# 104/104 - 20s - 193ms/step - accuracy: 0.5503 - loss: 0.9565 - val_accuracy: 0.4745 - val_loss: 1.2378 - learning_rate: 2.5000e-04
# Epoch 17/50
# 104/104 - 19s - 187ms/step - accuracy: 0.5596 - loss: 0.9392 - val_accuracy: 0.4115 - val_loss: 1.4428 - learning_rate: 2.5000e-04
# Epoch 18/50
# 104/104 - 21s - 203ms/step - accuracy: 0.5693 - loss: 0.9344 - val_accuracy: 0.4636 - val_loss: 1.2911 - learning_rate: 2.5000e-04
# Epoch 19/50
# 104/104 - 20s - 195ms/step - accuracy: 0.5696 - loss: 0.9277 - val_accuracy: 0.4691 - val_loss: 1.2230 - learning_rate: 2.5000e-04
# Epoch 20/50
# 104/104 - 21s - 199ms/step - accuracy: 0.5702 - loss: 0.8988 - val_accuracy: 0.5147 - val_loss: 1.2245 - learning_rate: 2.5000e-04
# Epoch 21/50
# 104/104 - 21s - 199ms/step - accuracy: 0.5696 - loss: 0.9087 - val_accuracy: 0.4984 - val_loss: 1.2263 - learning_rate: 2.5000e-04
# Epoch 22/50
# 104/104 - 21s - 205ms/step - accuracy: 0.5916 - loss: 0.8665 - val_accuracy: 0.5223 - val_loss: 1.1679 - learning_rate: 2.5000e-04
# Epoch 23/50
# 104/104 - 22s - 211ms/step - accuracy: 0.5913 - loss: 0.8722 - val_accuracy: 0.5212 - val_loss: 1.1758 - learning_rate: 2.5000e-04
# Epoch 24/50
# 104/104 - 21s - 206ms/step - accuracy: 0.5979 - loss: 0.8692 - val_accuracy: 0.5418 - val_loss: 1.1372 - learning_rate: 2.5000e-04
# Epoch 25/50
# 104/104 - 21s - 206ms/step - accuracy: 0.6096 - loss: 0.8426 - val_accuracy: 0.5255 - val_loss: 1.2093 - learning_rate: 2.5000e-04
# Epoch 26/50
# 104/104 - 23s - 220ms/step - accuracy: 0.6111 - loss: 0.8195 - val_accuracy: 0.5353 - val_loss: 1.1308 - learning_rate: 2.5000e-04
# Epoch 27/50
# 104/104 - 20s - 194ms/step - accuracy: 0.6108 - loss: 0.8178 - val_accuracy: 0.5396 - val_loss: 1.1026 - learning_rate: 2.5000e-04
# Epoch 28/50
# 104/104 - 21s - 198ms/step - accuracy: 0.6226 - loss: 0.8131 - val_accuracy: 0.5244 - val_loss: 1.1003 - learning_rate: 2.5000e-04
# Epoch 29/50
# 104/104 - 20s - 193ms/step - accuracy: 0.6316 - loss: 0.8088 - val_accuracy: 0.5722 - val_loss: 1.0873 - learning_rate: 2.5000e-04
# Epoch 30/50
# 104/104 - 21s - 199ms/step - accuracy: 0.6452 - loss: 0.7776 - val_accuracy: 0.5472 - val_loss: 1.0929 - learning_rate: 2.5000e-04
# Epoch 31/50
# 2025-12-11 20:22:31.809298: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 104/104 - 21s - 202ms/step - accuracy: 0.6416 - loss: 0.7824 - val_accuracy: 0.5689 - val_loss: 1.0474 - learning_rate: 2.5000e-04
# Epoch 32/50
# 104/104 - 22s - 208ms/step - accuracy: 0.6548 - loss: 0.7596 - val_accuracy: 0.5939 - val_loss: 1.0258 - learning_rate: 2.5000e-04
# Epoch 33/50
# 104/104 - 21s - 197ms/step - accuracy: 0.6515 - loss: 0.7394 - val_accuracy: 0.6135 - val_loss: 1.0207 - learning_rate: 2.5000e-04
# Epoch 34/50
# 104/104 - 20s - 197ms/step - accuracy: 0.6605 - loss: 0.7545 - val_accuracy: 0.6135 - val_loss: 1.0086 - learning_rate: 2.5000e-04
# Epoch 35/50
# 104/104 - 20s - 192ms/step - accuracy: 0.6593 - loss: 0.7413 - val_accuracy: 0.6080 - val_loss: 0.9900 - learning_rate: 2.5000e-04
# Epoch 36/50
# 104/104 - 20s - 195ms/step - accuracy: 0.6500 - loss: 0.7751 - val_accuracy: 0.5798 - val_loss: 1.0561 - learning_rate: 2.5000e-04
# Epoch 37/50
# 104/104 - 21s - 202ms/step - accuracy: 0.6515 - loss: 0.7440 - val_accuracy: 0.5798 - val_loss: 1.1175 - learning_rate: 2.5000e-04
# Epoch 38/50
# 104/104 - 21s - 199ms/step - accuracy: 0.6795 - loss: 0.6981 - val_accuracy: 0.6515 - val_loss: 0.9301 - learning_rate: 2.5000e-04
# Epoch 39/50
# 104/104 - 22s - 212ms/step - accuracy: 0.6822 - loss: 0.6845 - val_accuracy: 0.6124 - val_loss: 0.9889 - learning_rate: 2.5000e-04
# Epoch 40/50
# 104/104 - 25s - 238ms/step - accuracy: 0.6819 - loss: 0.6808 - val_accuracy: 0.6406 - val_loss: 0.9417 - learning_rate: 2.5000e-04
# Epoch 41/50
# 104/104 - 20s - 197ms/step - accuracy: 0.6714 - loss: 0.7202 - val_accuracy: 0.6460 - val_loss: 0.9259 - learning_rate: 2.5000e-04
# Epoch 42/50
# 104/104 - 20s - 189ms/step - accuracy: 0.6991 - loss: 0.6774 - val_accuracy: 0.6406 - val_loss: 0.9411 - learning_rate: 2.5000e-04
# Epoch 43/50
# 104/104 - 20s - 193ms/step - accuracy: 0.7036 - loss: 0.6516 - val_accuracy: 0.6515 - val_loss: 0.9250 - learning_rate: 2.5000e-04
# Epoch 44/50
# 104/104 - 20s - 190ms/step - accuracy: 0.7241 - loss: 0.6350 - val_accuracy: 0.6515 - val_loss: 0.9253 - learning_rate: 2.5000e-04
# Epoch 45/50
# 104/104 - 20s - 195ms/step - accuracy: 0.6988 - loss: 0.7464 - val_accuracy: 0.5744 - val_loss: 1.1251 - learning_rate: 2.5000e-04
# Epoch 46/50
# 104/104 - 22s - 212ms/step - accuracy: 0.7048 - loss: 0.6933 - val_accuracy: 0.6754 - val_loss: 0.8857 - learning_rate: 2.5000e-04
# Epoch 47/50
# 104/104 - 19s - 186ms/step - accuracy: 0.7211 - loss: 0.6337 - val_accuracy: 0.6482 - val_loss: 0.9312 - learning_rate: 2.5000e-04
# Epoch 48/50
# 104/104 - 21s - 203ms/step - accuracy: 0.7172 - loss: 0.6334 - val_accuracy: 0.6895 - val_loss: 0.8438 - learning_rate: 2.5000e-04
# Epoch 49/50
# 104/104 - 19s - 187ms/step - accuracy: 0.7473 - loss: 0.5859 - val_accuracy: 0.6916 - val_loss: 0.8490 - learning_rate: 2.5000e-04
# Epoch 50/50
# 104/104 - 20s - 195ms/step - accuracy: 0.7386 - loss: 0.6046 - val_accuracy: 0.6634 - val_loss: 0.8916 - learning_rate: 2.5000e-04

# %% [markdown]
# ## 📈 13. Evaluate Model

# %%
test_loss, test_acc = model.evaluate(test_ds)
print("Test Accuracy:", test_acc)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.6811 - loss: 0.8678
# Test Accuracy: 0.6328976154327393

# %% [markdown]
# ## 🔍 14. Confusion Matrix & Classification Report

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Get true and predicted labels for test set
y_true = []
y_pred = []

for images, labels in test_ds:
    preds = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))

y_true = np.array(y_true)
y_pred = np.array(y_pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step

# %%
# ----------------------------
# CONFUSION MATRIX
# ----------------------------
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
# ----------------------------
# CLASSIFICATION REPORT
# ----------------------------
report = classification_report(y_true, y_pred, target_names=class_names)
print("\nClassification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#   Blackheads       0.78      0.65      0.71       265
#         Cyst       0.61      0.71      0.66       189
#      Papules       0.53      0.60      0.56       202
#     Pustules       0.53      0.47      0.50       205
#   Whiteheads       0.89      0.98      0.93        57
#
#     accuracy                           0.63       918
#    macro avg       0.67      0.68      0.67       918
# weighted avg       0.64      0.63      0.63       918

# %% [markdown]
# ## 📊 15. Accuracy and Loss Curves

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
